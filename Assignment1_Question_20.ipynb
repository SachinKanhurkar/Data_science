# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np

# %%
data=pd.read_csv("Cars.csv")

# %%
data.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
data
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
n =max(data.shape)

# %%
n
# Out:
# 81

# %%
count = 0
for i in range(0, n):
    if data.iloc[i, 1]>38:
        count +=1
print(count)
prob= count/n
print(prob)
# Out:
# 33
# 0.4074074074074074

# %%
data.iloc[0, 1]
# Out:
# 53.70068138

# %%
count = 0
for i in range(0, n):
    if data.iloc[i, 1]<40:
        count +=1
print(count)
prob= count/n
print(prob)
# Out:
# 61
# 0.7530864197530864

# %%
count = 0
for i in range(0, n):
    if data.iloc[i, 1]>20 and data.iloc[i, 1]< 50 :
        count +=1
print(count)
prob= count/n
print(prob)
# Out:
# 69
# 0.8518518518518519

# %%
for v in range(0,len(data.columns)):
    x = data[data.columns[v]]
    #plt.hist(x)
    sns.displot(x, label='{}'.format(data.columns[v]))
    plt.xlabel('{}'.format(data.columns[v]))
    plt.ylabel('Frequency')    
    plt.title('Histogram of {}'.format(data.columns[v])) 
    plt.legend()
    plt.show()

# %%
for v in range(0,len(data.columns)):
    x = data[data.columns[v]] 
    sns.set(rc={"figure.figsize": (8, 4)}); np.random.seed(0)
    #plt.hist(x)
    sns.displot(x, label='{}'.format(data.columns[v]),  kde=True)
    plt.xlabel('{}'.format(data.columns[v]))
    plt.ylabel('Frequency')    
    plt.title('Histogram of {}'.format(data.columns[v]))       
    plt.grid(True)
    plt.legend()   
    plt.show()

# %%
for i in range(0, len(data.columns)):
    a= data.columns[i]
    print("For the {} dataset:-".format(a))
    print("Mean of {}: ".format(a), data[a].mean())
    print("Mode of {} ".format(a), data[a].mode())
    print("Median of {} ".format(a), data[a].median())
    print("Variance of {} ".format(a), data[a].var())
    print("Standard deviation of {} ".format(a), data[a].std())
    ran = max(data[a]) - min(data[a])
    print("Range of {} ".format(a), ran)
    print("\n")
# Out:
# For the HP dataset:-
# Mean of HP:  117.46913580246914
# Mode of HP  0    92
# dtype: int64
# Median of HP  100.0
# Variance of HP  3261.9521604938263
# Standard deviation of HP  57.11350243588486
# Range of HP  273
#
#
# For the MPG dataset:-
# Mean of MPG:  34.422075728024666
# Mode of MPG  0    29.629936
# dtype: float64
# Median of MPG  35.15272697
# Variance of MPG  83.38328288984461
# Standard deviation of MPG  9.131444731795982
# Range of MPG  41.59941849
#
#
# For the VOL dataset:-
# Mean of VOL:  98.76543209876543
# Mode of VOL  0    50
# dtype: int64
# Median of VOL  101.0
# Variance of VOL  497.35679012345673
# Standard deviation of VOL  22.301497486120898
# Range of VOL  110
#
#
# For the SP dataset:-
# Mean of SP:  121.5402721803703
# Mode of SP  0    118.288996
# dtype: float64
# Median of SP  118.20869840000002
# Variance of SP  201.11300150303705
# Standard deviation of SP  14.181431574528611
# Range of SP  70.03360619000001
#
#
# For the WT dataset:-
# Mean of WT:  32.41257691024691
# Mode of WT  0     15.712859
# 1     15.753535
# 2     15.769625
# 3     15.823060
# 4     15.847758
#         ...
# 76    42.778219
# 77    43.353123
# 78    43.390988
# 79    44.013139
# 80    52.997752
# Length: 81, dtype: float64
# Median of WT  32.73451818
# Variance of WT  56.14224661390445
# Standard deviation of WT  7.492812997393198
# Range of WT  37.28489383

# %%
data=pd.read_csv("wc-at.csv")

# %%
data.head(10)
# Out:
#    Waist     AT
# 0  74.75  25.72
# 1  72.60  25.89
# 2  81.80  42.60
# 3  83.95  42.80
# 4  74.65  29.84
# 5  71.85  21.68
# 6  80.90  29.08
# 7  83.40  32.98
# 8  63.50  11.44
# 9  73.20  32.22

# %%
data.shape
# Out:
# (109, 2)

# %%
for v in range(0,len(data.columns)):
    x = data[data.columns[v]] 
    sns.set(rc={"figure.figsize": (8, 4)}); np.random.seed(0)
    #plt.hist(x)
    sns.displot(x, label='{}'.format(data.columns[v]),  kde=True)
    plt.xlabel('{}'.format(data.columns[v]))
    plt.ylabel('Frequency')    
    plt.title('Histogram of {}'.format(data.columns[v]))       
    plt.grid(True)
    plt.legend()
    plt.show

# %%
for i in range(0, len(data.columns)):
    a= data.columns[i]
    print("For the {} dataset:-".format(a))
    print("Mean of {}: ".format(a), data[a].mean())
    print("Mode of {} ".format(a), data[a].mode())
    print("Median of {} ".format(a), data[a].median())
    print("Variance of {} ".format(a), data[a].var())
    print("Standard deviation of {} ".format(a), data[a].std())
    ran = max(data[a]) - min(data[a])
    print("Range of {} ".format(a), ran)
    print("\n")
# Out:
# For the Waist dataset:-
# Mean of Waist:  91.90183486238533
# Mode of Waist  0     94.5
# 1    106.0
# 2    108.5
# dtype: float64
# Median of Waist  90.8
# Variance of Waist  183.84962623173638
# Standard deviation of Waist  13.559115982678826
# Range of Waist  57.5
#
#
# For the AT dataset:-
# Mean of AT:  101.89403669724771
# Mode of AT  0    121.0
# 1    123.0
# dtype: float64
# Median of AT  96.54
# Variance of AT  3282.68983540605
# Standard deviation of AT  57.29476272231215
# Range of AT  241.56
